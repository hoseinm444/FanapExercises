# %% [markdown]
# <a href="https://colab.research.google.com/github/hoseinm444/FanapExercises/blob/main/FFCVS_Dec23_Python_Ex07_Hosein_Mohammadi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exercises 07
#
# Contrast Enhancement (CLAHE)

# %% [markdown]
# ##Exercise_01
#
# Enhance the original image to output image using CLAHE? (500 points)

# %% [markdown]
# ##solving with just colahe

# %%
#import
import cv2
import matplotlib.pyplot as plt
import numpy as np

#showing image using opencv
def show_img_cv(img_title, img):
    cv2.imshow(img_title, img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

#showing image using matplotlib
def show_img_plt(img, c_map ='gray', fig_hight=8, fig_width=6):
    plt.figure(figsize=(fig_hight, fig_width), dpi=100)
    plt.imshow(img, cmap=c_map)

#display hist using matplotlib
def display_hist_plt(img, bins=256, range=(0, 256)):
    plt.figure(figsize=(4, 2), dpi=100)
    plt.hist(img.flat, bins=bins, range=range)
    plt.show()

# %%
low_contrast_img = cv2.imread(r'sample.jpg', 0)
show_img_plt(low_contrast_img)

# %%
display_hist_plt(low_contrast_img)

# %%
#CLAHE
clahe_100 =cv2.createCLAHE(clipLimit=100)
clahe_img = clahe_100.apply(low_contrast_img)
show_img_plt(clahe_img)

# %%
display_hist_plt(clahe_img)

# %% [markdown]
# ##solving with colahe and other method

# %%
img_colahe_other = low_contrast_img.copy()
he_img = cv2.equalizeHist(img_colahe_other)
show_img_plt(he_img)

# %%
display_hist_plt(he_img)

# %%
clahe_100 =cv2.createCLAHE(clipLimit=100)
clahe_img_2 = clahe_100.apply(he_img)
show_img_plt(clahe_img_2)

# %%
display_hist_plt(clahe_img_2)
